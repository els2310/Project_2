# %%
import requests
import json
import datetime
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Getting lates news from Cryptocomapre API 
crypcomp_api_news = "https://min-api.cryptocompare.com/data/v2/news/?lang=EN"

crypcomp_news_req = requests.get(crypcomp_api_news).json()

# Create the Bitcoin sentiment scores DataFrame
crypto_sentiments = []

for article in crypcomp_news_req["Data"]:
    try:
        text = article["body"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        title = article["title"]
        url = article["url"]
        
        crypto_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text,
            "Title": title,
            "URL": url
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
crypto_df = pd.DataFrame(crypto_sentiments)

# Reorder DataFrame columns
cols = ["Title", "URL", "Compound", "Positive", "Negative", "Neutral"]
crypto_df = crypto_df[cols]
crypto_df.head(10)
# Out:
#                                                Title  \
# 0               Will Ripple Ever Issue a Stablecoin?
# 1  Bitstamp imposes KYC for Dutch traders withdra...
# 2  South Korean Carrier SKT Launches Blockchain-p...
# 3  Ethereum price poised to skyrocket 41% to a ne...
# 4  The Elon Musk Effect? Dogecoin Searches Spike ...
# 5  Institutional Buying, Grayscale Bitcoin Trust ...
# 6  EU Seeks to Curb Reliance on US Dollar After A...
# 7  Crypto Analyst Luke Martin Gives DeFi Picks to...
# 8  CoinShares to launch $200m Bitcoin ETP on Swis...
# 9  Ethereum trend analysis – ETH/USD knocks at $1...
#
#                                                  URL  Compound  Positive  \
# 0  https://cryptobriefing.com/will-ripple-ever-is...    0.0000     0.000
# 1  https://cointelegraph.com/news/bitstamp-impose...   -0.2960     0.000
# 2  https://cryptonews.com/news/south-korean-carri...    0.0000     0.000
# 3                      https://coingape.com/79723-2/    0.4019     0.087
# ...

# %%
# Getting lates news from Cryptocomapre API 
crypcomp_api_coinsinfo = "https://min-api.cryptocompare.com/data/top/mktcapfull?limit=10&tsym=USD"
# Submit request and format output
crypcomp_coinsinfo_req = requests.get(crypcomp_api_coinsinfo).json()
coin_0_info = crypcomp_coinsinfo_req['Data'][0]['CoinInfo']
coin_1_info = crypcomp_coinsinfo_req['Data'][1]['CoinInfo']
coin_2_info = crypcomp_coinsinfo_req['Data'][2]['CoinInfo']
coin_3_info = crypcomp_coinsinfo_req['Data'][3]['CoinInfo']
coin_4_info = crypcomp_coinsinfo_req['Data'][4]['CoinInfo']
coin_5_info = crypcomp_coinsinfo_req['Data'][5]['CoinInfo']
coin_6_info = crypcomp_coinsinfo_req['Data'][6]['CoinInfo']
coin_7_info = crypcomp_coinsinfo_req['Data'][7]['CoinInfo']
coin_8_info = crypcomp_coinsinfo_req['Data'][8]['CoinInfo']
coin_9_info = crypcomp_coinsinfo_req['Data'][9]['CoinInfo']

coin_0_raw = crypcomp_coinsinfo_req['Data'][0]['RAW']['USD']
coin_1_raw = crypcomp_coinsinfo_req['Data'][1]['RAW']['USD']
coin_2_raw = crypcomp_coinsinfo_req['Data'][2]['RAW']['USD']
coin_3_raw = crypcomp_coinsinfo_req['Data'][3]['RAW']['USD']
coin_4_raw = crypcomp_coinsinfo_req['Data'][4]['RAW']['USD']
coin_5_raw = crypcomp_coinsinfo_req['Data'][5]['RAW']['USD']
coin_6_raw = crypcomp_coinsinfo_req['Data'][6]['RAW']['USD']
coin_7_raw = crypcomp_coinsinfo_req['Data'][7]['RAW']['USD']
coin_8_raw = crypcomp_coinsinfo_req['Data'][8]['RAW']['USD']
coin_9_raw = crypcomp_coinsinfo_req['Data'][9]['RAW']['USD']

# %%
coin_0_fullname = coin_0_info['FullName']
coin_0_rating = coin_0_info['Rating']['Weiss']['Rating']
coin_0_launchdate = coin_0_info['AssetLaunchDate']
coin_0_launchdate = datetime.datetime.strptime(coin_0_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_0_symbol = coin_0_raw['FROMSYMBOL']
coin_0_price = coin_0_raw['PRICE']

coin_1_fullname = coin_1_info['FullName']
coin_1_launchdate = coin_1_info['AssetLaunchDate']
coin_1_launchdate = datetime.datetime.strptime(coin_1_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_1_symbol = coin_1_raw['FROMSYMBOL']
coin_1_price = coin_1_raw['PRICE']

coin_2_fullname = coin_2_info['FullName']
coin_2_launchdate = coin_2_info['AssetLaunchDate']
coin_2_launchdate = datetime.datetime.strptime(coin_2_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_2_symbol = coin_2_raw['FROMSYMBOL']
coin_2_price = coin_2_raw['PRICE']

coin_3_fullname = coin_3_info['FullName']
coin_3_launchdate = coin_3_info['AssetLaunchDate']
coin_3_launchdate = datetime.datetime.strptime(coin_3_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_3_symbol = coin_3_raw['FROMSYMBOL']
coin_3_price = coin_3_raw['PRICE']

coin_4_fullname = coin_4_info['FullName']
coin_4_launchdate = coin_4_info['AssetLaunchDate']
coin_4_launchdate = datetime.datetime.strptime(coin_4_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_4_symbol = coin_4_raw['FROMSYMBOL']
coin_4_price = coin_4_raw['PRICE']

coin_5_fullname = coin_5_info['FullName']
coin_5_launchdate = coin_5_info['AssetLaunchDate']
coin_5_launchdate = datetime.datetime.strptime(coin_5_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_5_symbol = coin_5_raw['FROMSYMBOL']
coin_5_price = coin_5_raw['PRICE']

coin_6_fullname = coin_6_info['FullName']
coin_6_launchdate = coin_6_info['AssetLaunchDate']
coin_6_launchdate = datetime.datetime.strptime(coin_6_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_6_symbol = coin_6_raw['FROMSYMBOL']
coin_6_price = coin_6_raw['PRICE']

coin_7_fullname = coin_7_info['FullName']
coin_7_launchdate = coin_7_info['AssetLaunchDate']
coin_7_launchdate = datetime.datetime.strptime(coin_7_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_7_symbol = coin_7_raw['FROMSYMBOL']
coin_7_price = coin_7_raw['PRICE']

coin_8_fullname = coin_8_info['FullName']
coin_8_launchdate = coin_8_info['AssetLaunchDate']
coin_8_launchdate = datetime.datetime.strptime(coin_8_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_8_symbol = coin_8_raw['FROMSYMBOL']
coin_8_price = coin_8_raw['PRICE']

coin_9_fullname = coin_9_info['FullName']
coin_9_launchdate = coin_9_info['AssetLaunchDate']
coin_9_launchdate = datetime.datetime.strptime(coin_9_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
coin_9_symbol = coin_9_raw['FROMSYMBOL']
coin_9_price = coin_9_raw['PRICE']

# %%
print(
"Here is a list of the top 10 cryptocurrencies by volume: \n"
f"1. {coin_0_fullname} was launched on {coin_0_launchdate} uses the ticker '{coin_0_symbol}', most recent price in USD of ${('{:,}'.format(coin_0_price))} \n"
f"2. {coin_1_fullname} was launched on {coin_1_launchdate} uses the ticker '{coin_1_symbol}', most recent price in USD of ${('{:,}'.format(coin_1_price))} \n"
f"3. {coin_2_fullname} was launched on {coin_2_launchdate} uses the ticker '{coin_2_symbol}', most recent price in USD of ${('{:,}'.format(coin_2_price))} \n"
f"4. {coin_3_fullname} was launched on {coin_3_launchdate} uses the ticker '{coin_3_symbol}', most recent price in USD of ${('{:,}'.format(coin_3_price))} \n"
f"5. {coin_4_fullname} was launched on {coin_4_launchdate} uses the ticker '{coin_4_symbol}', most recent price in USD of ${('{:,}'.format(coin_4_price))} \n"
f"6. {coin_5_fullname} was launched on {coin_5_launchdate} uses the ticker '{coin_5_symbol}', most recent price in USD of ${('{:,}'.format(coin_5_price))} \n"
f"7. {coin_6_fullname} was launched on {coin_6_launchdate} uses the ticker '{coin_6_symbol}', most recent price in USD of ${('{:,}'.format(coin_6_price))} \n"
f"8. {coin_7_fullname} was launched on {coin_7_launchdate} uses the ticker '{coin_7_symbol}', most recent price in USD of ${('{:,}'.format(coin_7_price))} \n"
f"9. {coin_8_fullname} was launched on {coin_8_launchdate} uses the ticker '{coin_8_symbol}', most recent price in USD of ${('{:,}'.format(coin_8_price))} \n"
f"10. {coin_9_fullname} was launched on {coin_9_launchdate} uses the ticker '{coin_9_symbol}', most recent price in USD of ${('{:,}'.format(coin_9_price))} \n"
)
# Out:
# Here is a list of the top 10 cryptocurrencies by volume:
# 1. Bitcoin was launched on 01/03/09 uses the ticker 'BTC', most recent price in USD of $36,852.49
# 2. Ethereum was launched on 07/30/15 uses the ticker 'ETH', most recent price in USD of $1,327.96
# 3. XRP was launched on 01/01/13 uses the ticker 'XRP', most recent price in USD of $0.2892
# 4. Tether was launched on 10/06/14 uses the ticker 'USDT', most recent price in USD of $1.002
# 5. Chainlink was launched on 09/19/17 uses the ticker 'LINK', most recent price in USD of $21.88
# 6. Polkadot was launched on 08/18/20 uses the ticker 'DOT', most recent price in USD of $16.41
# 7. Stellar was launched on 07/31/14 uses the ticker 'XLM', most recent price in USD of $0.3041
# 8. Cardano was launched on 10/05/17 uses the ticker 'ADA', most recent price in USD of $0.3683
# 9. Litecoin was launched on 10/13/11 uses the ticker 'LTC', most recent price in USD of $155.73
# ...

# %%
def general_cryptocurrency_info():
    
    # Getting lates news from Cryptocomapre API 
    crypcomp_api_coinsinfo = "https://min-api.cryptocompare.com/data/top/mktcapfull?limit=10&tsym=USD"
    
    # Submit request and format output
    crypcomp_coinsinfo_req = requests.get(crypcomp_api_coinsinfo).json()
    coin_0_info = crypcomp_coinsinfo_req['Data'][0]['CoinInfo']
    coin_1_info = crypcomp_coinsinfo_req['Data'][1]['CoinInfo']
    coin_2_info = crypcomp_coinsinfo_req['Data'][2]['CoinInfo']
    coin_3_info = crypcomp_coinsinfo_req['Data'][3]['CoinInfo']
    coin_4_info = crypcomp_coinsinfo_req['Data'][4]['CoinInfo']
    coin_5_info = crypcomp_coinsinfo_req['Data'][5]['CoinInfo']
    coin_6_info = crypcomp_coinsinfo_req['Data'][6]['CoinInfo']
    coin_7_info = crypcomp_coinsinfo_req['Data'][7]['CoinInfo']
    coin_8_info = crypcomp_coinsinfo_req['Data'][8]['CoinInfo']
    coin_9_info = crypcomp_coinsinfo_req['Data'][9]['CoinInfo']

    coin_0_raw = crypcomp_coinsinfo_req['Data'][0]['RAW']['USD']
    coin_1_raw = crypcomp_coinsinfo_req['Data'][1]['RAW']['USD']
    coin_2_raw = crypcomp_coinsinfo_req['Data'][2]['RAW']['USD']
    coin_3_raw = crypcomp_coinsinfo_req['Data'][3]['RAW']['USD']
    coin_4_raw = crypcomp_coinsinfo_req['Data'][4]['RAW']['USD']
    coin_5_raw = crypcomp_coinsinfo_req['Data'][5]['RAW']['USD']
    coin_6_raw = crypcomp_coinsinfo_req['Data'][6]['RAW']['USD']
    coin_7_raw = crypcomp_coinsinfo_req['Data'][7]['RAW']['USD']
    coin_8_raw = crypcomp_coinsinfo_req['Data'][8]['RAW']['USD']
    coin_9_raw = crypcomp_coinsinfo_req['Data'][9]['RAW']['USD']
    
    coin_0_fullname = coin_0_info['FullName']
    coin_0_rating = coin_0_info['Rating']['Weiss']['Rating']
    coin_0_launchdate = coin_0_info['AssetLaunchDate']
    coin_0_launchdate = datetime.datetime.strptime(coin_0_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_0_symbol = coin_0_raw['FROMSYMBOL']
    coin_0_price = coin_0_raw['PRICE']

    coin_1_fullname = coin_1_info['FullName']
    coin_1_launchdate = coin_1_info['AssetLaunchDate']
    coin_1_launchdate = datetime.datetime.strptime(coin_1_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_1_symbol = coin_1_raw['FROMSYMBOL']
    coin_1_price = coin_1_raw['PRICE']

    coin_2_fullname = coin_2_info['FullName']
    coin_2_launchdate = coin_2_info['AssetLaunchDate']
    coin_2_launchdate = datetime.datetime.strptime(coin_2_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_2_symbol = coin_2_raw['FROMSYMBOL']
    coin_2_price = coin_2_raw['PRICE']

    coin_3_fullname = coin_3_info['FullName']
    coin_3_launchdate = coin_3_info['AssetLaunchDate']
    coin_3_launchdate = datetime.datetime.strptime(coin_3_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_3_symbol = coin_3_raw['FROMSYMBOL']
    coin_3_price = coin_3_raw['PRICE']

    coin_4_fullname = coin_4_info['FullName']
    coin_4_launchdate = coin_4_info['AssetLaunchDate']
    coin_4_launchdate = datetime.datetime.strptime(coin_4_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_4_symbol = coin_4_raw['FROMSYMBOL']
    coin_4_price = coin_4_raw['PRICE']

    coin_5_fullname = coin_5_info['FullName']
    coin_5_launchdate = coin_5_info['AssetLaunchDate']
    coin_5_launchdate = datetime.datetime.strptime(coin_5_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_5_symbol = coin_5_raw['FROMSYMBOL']
    coin_5_price = coin_5_raw['PRICE']

    coin_6_fullname = coin_6_info['FullName']
    coin_6_launchdate = coin_6_info['AssetLaunchDate']
    coin_6_launchdate = datetime.datetime.strptime(coin_6_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_6_symbol = coin_6_raw['FROMSYMBOL']
    coin_6_price = coin_6_raw['PRICE']

    coin_7_fullname = coin_7_info['FullName']
    coin_7_launchdate = coin_7_info['AssetLaunchDate']
    coin_7_launchdate = datetime.datetime.strptime(coin_7_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_7_symbol = coin_7_raw['FROMSYMBOL']
    coin_7_price = coin_7_raw['PRICE']

    coin_8_fullname = coin_8_info['FullName']
    coin_8_launchdate = coin_8_info['AssetLaunchDate']
    coin_8_launchdate = datetime.datetime.strptime(coin_8_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_8_symbol = coin_8_raw['FROMSYMBOL']
    coin_8_price = coin_8_raw['PRICE']

    coin_9_fullname = coin_9_info['FullName']
    coin_9_launchdate = coin_9_info['AssetLaunchDate']
    coin_9_launchdate = datetime.datetime.strptime(coin_9_launchdate, '%Y-%m-%d').strftime('%m/%d/%y')
    coin_9_symbol = coin_9_raw['FROMSYMBOL']
    coin_9_price = coin_9_raw['PRICE']
    
    return print("Here is a list of the top 10 cryptocurrencies by volume: \n"
    f"1. {coin_0_fullname} was launched on {coin_0_launchdate} uses the ticker '{coin_0_symbol}', most recent price in USD of ${('{:,}'.format(coin_0_price))} \n"
    f"2. {coin_1_fullname} was launched on {coin_1_launchdate} uses the ticker '{coin_1_symbol}', most recent price in USD of ${('{:,}'.format(coin_1_price))} \n"
    f"3. {coin_2_fullname} was launched on {coin_2_launchdate} uses the ticker '{coin_2_symbol}', most recent price in USD of ${('{:,}'.format(coin_2_price))} \n"
    f"4. {coin_3_fullname} was launched on {coin_3_launchdate} uses the ticker '{coin_3_symbol}', most recent price in USD of ${('{:,}'.format(coin_3_price))} \n"
    f"5. {coin_4_fullname} was launched on {coin_4_launchdate} uses the ticker '{coin_4_symbol}', most recent price in USD of ${('{:,}'.format(coin_4_price))} \n"
    f"6. {coin_5_fullname} was launched on {coin_5_launchdate} uses the ticker '{coin_5_symbol}', most recent price in USD of ${('{:,}'.format(coin_5_price))} \n"
    f"7. {coin_6_fullname} was launched on {coin_6_launchdate} uses the ticker '{coin_6_symbol}', most recent price in USD of ${('{:,}'.format(coin_6_price))} \n"
    f"8. {coin_7_fullname} was launched on {coin_7_launchdate} uses the ticker '{coin_7_symbol}', most recent price in USD of ${('{:,}'.format(coin_7_price))} \n"
    f"9. {coin_8_fullname} was launched on {coin_8_launchdate} uses the ticker '{coin_8_symbol}', most recent price in USD of ${('{:,}'.format(coin_8_price))} \n"
    f"10. {coin_9_fullname} was launched on {coin_9_launchdate} uses the ticker '{coin_9_symbol}', most recent price in USD of ${('{:,}'.format(coin_9_price))} \n"
    )

# %%
general_cryptocurrency_info()
# Out:
# Here is a list of the top 10 cryptocurrencies by volume:
# 1. Bitcoin was launched on 01/03/09 uses the ticker 'BTC', most recent price in USD of $36,849.18
# 2. Ethereum was launched on 07/30/15 uses the ticker 'ETH', most recent price in USD of $1,327.57
# 3. XRP was launched on 01/01/13 uses the ticker 'XRP', most recent price in USD of $0.2892
# 4. Tether was launched on 10/06/14 uses the ticker 'USDT', most recent price in USD of $1.002
# 5. Chainlink was launched on 09/19/17 uses the ticker 'LINK', most recent price in USD of $21.88
# 6. Polkadot was launched on 08/18/20 uses the ticker 'DOT', most recent price in USD of $16.41
# 7. Stellar was launched on 07/31/14 uses the ticker 'XLM', most recent price in USD of $0.3041
# 8. Cardano was launched on 10/05/17 uses the ticker 'ADA', most recent price in USD of $0.3683
# 9. Litecoin was launched on 10/13/11 uses the ticker 'LTC', most recent price in USD of $155.73
# ...
